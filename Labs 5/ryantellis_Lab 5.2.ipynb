# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 5.2
# # *The Perceptron*

# %% [markdown]
# The perceptron is the basic unit of a neural network. It learns by adjusting the weights applied to each of its inputs until the error at its output is minimised.
#
# The example in this lab uses the stochastic gradient descent (SGD) algorithm to optimise the weights of a perceptron applied to a 2D classification problem.

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# The training dataset has 2 numeric features (X is 2D) and a binary response (y = +/-1):

# %%
X = np.array([[-1, 3], [1, 4], [4, 5], [-1, 5], [2, 6], [5, 6]])
y = np.array([-1, -1, -1, 1, 1, 1])

# %% [markdown]
# Here is the training data, along with a candidate hyperplane that separates the classes:

# %%
def plotData(X):
    for d, sample in enumerate(X):
        # Plot the negative samples
        if d < 3:
            plt.scatter(sample[0], sample[1], s = 100, marker = '_', color = 'blue')
        # Plot the positive samples
        else:
            plt.scatter(sample[0], sample[1], s = 100, marker = '+', color = 'blue')
    plt.xlabel('X0')
    plt.ylabel('X1')

plotData(X)

# Print one possible hyperplane that separates the two classes:
plt.plot([-2, 6], [4, 5], linestyle = 'dashed');  #-2 and 4 for the start of the hyperplane and 6 and 5 for the end
plt.show()

# %% [markdown]
# We need to include a bias term (-1) in the X array. This will transform the decision boundary so that the sign of the dot product of any data point with the weights vector, represented in the code below by $$⟨x[i], w⟩ = {\rm wt}[0]\times x_0 + {\rm wt}[1]\times x_1 + {\rm wt}[2]\times(-1),$$  will determine class membership:

# %%
X = np.array([ [-1, 3, -1], [1, 4, -1], [4, 5, -1], [-1, 5, -1], [2, 6, -1], [5, 6, -1]])

# %% [markdown]
# Here is a simple implementation of the stochastic gradient descent algorithm for computing the weights:

# %%
def calc_perceptron_weights(Xt, Yt, eta = 1, epochs = 20):

    # Initialize the weight vector for the perceptron with zeros:
    wt = np.zeros(len(Xt[0]))

    for t in range(epochs):

        # Iterate over each sample in the data set:
        for i, x in enumerate(Xt):

            # Test for misclassification: y * ⟨x[i], w⟩ <= 0:
            if (np.dot(Xt[i], wt) * Yt[i]) <= 0:

                # Update weights:
                wt = wt + eta * Xt[i] * Yt[i]

    return wt

# %% [markdown]
# Compute the weights using default learning rate (eta = 1) and number of epochs = 10:

# %%
w = calc_perceptron_weights(X, y, epochs = 10)
print(w)
# Out:
# [2. 9. 4.]

# %% [markdown]
# Did it work? Let's check the decision boundary (hyperplane) and try some predictions:

# %%
def plotHyperplane(wt):

    xx = np.linspace(-2,6)
    yy = (-wt[0]*xx + wt[2])/wt[1]
    plt.plot(xx, yy);

plotData(X)
plotHyperplane(w)

# Test samples:
plt.scatter(2, 4, s = 120, marker = '_', color = 'red')
plt.scatter(4, 6, s = 120, marker = '+', color = 'red')
plt.show()

# %% [markdown]
# So far, all of the negatively labelled points are misclassified!
#
# Let's a look at how the model training actually proceeds. The error at each epoch is calculated using a hinge-loss function:

# %%
def perceptron_plot(Xt, Yt, eta = 1, epochs = 10):

    wt = np.zeros(len(Xt[0]))
    errors = []

    for t in range(epochs):
        error = 0
        for i, x in enumerate(Xt):
            if (np.dot(Xt[i], wt) * Yt[i]) <= 0:
                error += -(np.dot(Xt[i], wt) * Yt[i])
                wt += eta * Xt[i] * Yt[i]
        errors.append(error)

    plt.plot(errors);
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return wt

print(perceptron_plot(X, y))
plt.show()
# Out:
# [2. 9. 4.]

# %% [markdown]
# So, 10 epochs clearly wasn't enough for the SGD algorithm to converge.
#
# Try increasing `epochs` until the error goes to zero, then replot the test data and decision boundary:

# %%
#increased epochs to 39 seems to bring loss to 0.
w= perceptron_plot(X, y, epochs=39)
plt.show()

# %%
#replot the data to confirm correct hyperplane
print(w)
plotData(X)
plotHyperplane(w)
plt.show()
# Out:
# [-1.  5. 23.]

# %% [markdown]
# Show how to manually compute class membership for a new data point Xi = [3.5, 3.3] using just the weights determined above:

# %%
#bias term = -1
Xi = [3.5, 3.3, -1]

# %%
w
# Out:
# array([-1.,  5., 23.])

# %%
#define class membership
def classmember (Xi, wt):
    t = np.dot(Xi, w)
    if t >= 0:
        return('Class is +')
    elif t < 0:
        return('class is -')

# %%
classmember (Xi, w)
# Out:
# 'class is -'

# %% [markdown]
# In a similar manner make sure each of the training data points is correctly classified:

# %%
print('Training data set:')
print(X)
print()
print('y:', y)
print('weights', w)
# Out:
# Training data set:
# [[-1  3 -1]
#  [ 1  4 -1]
#  [ 4  5 -1]
#  [-1  5 -1]
#  [ 2  6 -1]
#  [ 5  6 -1]]
#
# y: [-1 -1 -1  1  1  1]
# weights [-1.  5. 23.]

# %%
for i, x in enumerate(X):
    prediction = classmember (x, w)
    actual = y[i]
    print('Vector: ', x[:2])
    result = 'Incorrect' if prediction == actual else 'Correct'
    print(f"Sample {i+1}: Predicted {prediction}, Actual {actual}")
# Out:
# Vector:  [-1  3]
# Sample 1: Predicted class is -, Actual -1
# Vector:  [1 4]
# Sample 2: Predicted class is -, Actual -1
# Vector:  [4 5]
# Sample 3: Predicted class is -, Actual -1
# Vector:  [-1  5]
# Sample 4: Predicted Class is +, Actual 1
# Vector:  [2 6]
# Sample 5: Predicted Class is +, Actual 1
# Vector:  [5 6]
# Sample 6: Predicted Class is +, Actual 1

# %% [markdown]
# ## === End ===

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
