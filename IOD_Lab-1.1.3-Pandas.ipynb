# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Pandas Exploration
#
# This lab provides practice in using the pandas library to carry out the following tasks:
#
# 1. Understanding data types
# 2. Querying a dataframe
# 3. Using the index to sort a dataframe
# 4. Visualising and summarising columns of a dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
path = r'C:\Users\ryant\Desktop\IOD\DATA\Employee-attrition.csv'
df = pd.read_csv(path) # this comes from the DATA folder
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 4                1/1/1900   56                 21    Vancouver
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 0             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 4             Executive           CEO          35            M        Male
# ...                 ...           ...         ...          ...         ...
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# ...               ...             ...          ...         ...           ...
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %%
df.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
df.tail(10)
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49643        8188  10/1/2014 0:00    10/22/1993        4/25/2013
# 49644        8214  12/1/2014 0:00      1/6/1994         6/5/2013
# 49645        8223  10/1/2013 0:00     2/11/1994        6/24/2013
# 49646        8226   9/1/2013 0:00     2/16/1994        6/26/2013
# 49647        8231  12/1/2015 0:00      3/1/1994         7/3/2013
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49643          10/25/2014   21                  1     Victoria
# 49644          12/30/2014   20                  1        Haney
# 49645          10/17/2013   19                  0        Trail
# 49646           9/14/2013   19                  0     Victoria
# 49647          12/30/2015   21                  2    Princeton
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name      job_title  store_name gender_short gender_full  \
# 49643  Customer Service        Cashier          46            F      Female
# 49644           Produce  Produce Clerk          14            F      Female
# 49645  Customer Service        Cashier          33            M        Male
# 49646  Customer Service        Cashier          46            F      Female
# 49647  Customer Service        Cashier          27            M        Male
# 49648             Dairy   Dairy Person          34            M        Male
# 49649  Customer Service        Cashier          44            F      Female
# 49650  Customer Service        Cashier          39            F      Female
# 49651  Customer Service        Cashier          16            F      Female
# 49652  Customer Service        Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49643      Resignaton     Voluntary         2014  TERMINATED        STORES
# 49644          Layoff   Involuntary         2014  TERMINATED        STORES
# 49645      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49646      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49647          Layoff   Involuntary         2015  TERMINATED        STORES
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %%
df.sample(10)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 41920        7017  12/31/2014 0:00    12/24/1984        8/26/2008
# 40225        6795  12/31/2011 0:00     3/26/1983        9/25/2007
# 23263        4961  12/31/2010 0:00     9/16/1968        1/23/2000
# 48652        3358   11/1/2008 0:00    11/22/1943        5/30/1995
# 7335         2631  12/31/2013 0:00     4/26/1956         7/8/1993
# 16179        3982  12/31/2009 0:00      4/2/1963         3/7/1997
# 48009        8282  12/31/2015 0:00      8/7/1994        9/25/2013
# 42544        7103  12/31/2013 0:00      7/6/1985        12/7/2008
# 26373        5312  12/31/2014 0:00     3/20/1971        5/21/2001
# 41527        6965  12/31/2009 0:00      7/3/1984        5/27/2008
#
#       terminationdate_key  age  length_of_service        city_name  \
# 41920            1/1/1900   30                  6          Nanaimo
# 40225            1/1/1900   28                  4        Vancouver
# 23263            1/1/1900   42                 10       Chilliwack
# 48652          11/22/2008   65                 13         Victoria
# 7335             1/1/1900   57                 20         Kamloops
# 16179            1/1/1900   46                 12  New Westminster
# 48009            1/1/1900   21                  2           Vernon
# 42544          12/30/2014   28                  5    Cortes Island
# 26373            1/1/1900   43                 13          Nanaimo
# 41527            1/1/1900   25                  1          Burnaby
#
#         department_name      job_title  store_name gender_short gender_full  \
# 41920   Processed Foods  Shelf Stocker          18            M        Male
# 40225  Customer Service        Cashier          43            F      Female
# 23263            Bakery          Baker           6            F      Female
# 48652             Meats    Meat Cutter          37            F      Female
# 7335              Meats    Meat Cutter          15            F      Female
# 16179           Produce  Produce Clerk          21            M        Male
# 48009  Customer Service        Cashier          36            F      Female
# 42544             Dairy   Dairy Person           7            F      Female
# 26373             Dairy   Dairy Person          18            F      Female
# 41527             Dairy   Dairy Person           5            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 41920  Not Applicable  Not Applicable         2014      ACTIVE        STORES
# 40225  Not Applicable  Not Applicable         2011      ACTIVE        STORES
# 23263  Not Applicable  Not Applicable         2010      ACTIVE        STORES
# 48652      Retirement       Voluntary         2008  TERMINATED        STORES
# 7335   Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 16179  Not Applicable  Not Applicable         2009      ACTIVE        STORES
# 48009  Not Applicable  Not Applicable         2015      ACTIVE        STORES
# 42544  Not Applicable  Not Applicable         2013      ACTIVE        STORES
# 26373  Not Applicable  Not Applicable         2014      ACTIVE        STORES
# 41527  Not Applicable  Not Applicable         2009      ACTIVE        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find the shape of the dataframe

# %%
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find the data types of the dataframe

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find the number of data types in the dataframe
#
#
#
# ```
# Expected Output:
# object    13
# int64      5
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# Name: count, dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore the difference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # 2. Querying the Dataframe

# %% [markdown]
# #### 2.A Check Values of the `job_title` column

# %%
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find how many rows are in each job title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# CEO                                  10
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Stores                            10
# VP Human Resources                   10
# VP Finance                           10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Exec Assistant, Legal Counsel        10
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounting                  9
# Director, Investments                 4
# Director, Labor Relations             4
# Director, Compensation                4
# Director, Audit                       4
# Director, Training                    4
# Name: count, dtype: int64

# %% [markdown]
# #### 2.C Find rows where `job_title` is CEO

# %%
df[df['job_title'] == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 2.D Describe `age`
#
# Find the count, mean, std, min, max of the column 'age'

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# #### 2.E Group by `age` and find how many there are of each age

# %%
df['age'].value_counts()
# Out:
# age
# 27    1235
# 29    1227
# 28    1225
# 50    1218
# 30    1212
# 26    1210
# 51    1207
# 25    1197
# 49    1196
# 35    1189
# 34    1188
# 53    1188
# 52    1188
# 48    1180
# 36    1176
# 47    1173
# 55    1168
# 33    1164
# 46    1161
# 54    1159
# 44    1157
# 38    1156
# 56    1154
# 32    1153
# 42    1152
# 43    1150
# 37    1149
# 31    1146
# 39    1142
# 45    1141
# 41    1135
# 58    1130
# 57    1130
# 40    1130
# 59    1128
# 24    1111
# 60    1109
# 23     960
# 22     815
# 61     757
# 62     712
# 21     703
# 63     667
# 64     646
# 65     593
# 20     408
# 19     158
# Name: count, dtype: int64

# %% [markdown]
# ##### 2.F [BONUS] Describe all numeric columns of the dataframe
#
# Find the count, mean, std, min, max of all columns of the dataframe

# %%
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Make the index meaningful by making `EmployeeID` the index

# %%
df.set_index('EmployeeID', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15660\3154261504.py in ?()
# ----> 1 df.set_index('EmployeeID', inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['EmployeeID'] are in the columns"

# %% [markdown]
# #### 3.A Find a specific row using the index

# %%
df.loc[41920]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 41920
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 df.loc[41920]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 41920

# %% [markdown]
# #### 3.B Sort the dataframe using the index

# %%
df.sort_index()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8335        12/31/2013 0:00    12/28/1994       12/10/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# ...                        ...  ...                ...        ...
# 8335                  1/1/1900   19                  0  Vancouver
# 8335                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   19                  0  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# ...                    ...           ...         ...          ...         ...
# 8335                 Dairy  Dairy Person          35            F      Female
# 8335                 Dairy  Dairy Person          35            F      Female
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# ...                    ...             ...          ...     ...           ...
# 8335        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2014  ACTIVE        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# ##### 3.C [BONUS] Sort the dataframe using `age`

# %%
df.sort_values('age')
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8325        12/31/2013 0:00     12/7/1994       11/29/2013
# 8253        12/31/2013 0:00     5/15/1994        8/12/2013
# 8252        12/31/2013 0:00     5/10/1994         8/9/2013
# 8251        12/31/2013 0:00      5/7/1994         8/7/2013
# 8250        12/31/2013 0:00     4/26/1994         8/2/2013
# ...                     ...           ...              ...
# 3262          8/1/2008 0:00     8/23/1943        2/28/1995
# 3248          8/1/2008 0:00     8/14/1943        2/19/1995
# 4948          7/1/2013 0:00      7/9/1948        1/14/2000
# 3356         11/1/2008 0:00    11/18/1943        5/26/1995
# 4138          2/1/2011 0:00     2/12/1946        8/20/1997
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 8325                  1/1/1900   19                  0        Cranbrook
# 8253                  1/1/1900   19                  0  North Vancouver
# 8252                  1/1/1900   19                  0         Victoria
# 8251                  1/1/1900   19                  0        Vancouver
# 8250                  1/1/1900   19                  0          Burnaby
# ...                        ...  ...                ...              ...
# 3262                 8/23/2008   65                 13          Nanaimo
# 3248                 8/14/2008   65                 13        Vancouver
# 4948                  7/9/2013   65                 13          Burnaby
# 3356                11/18/2008   65                 13          Nanaimo
# 4138                 2/12/2011   65                 13           Surrey
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 8325        Customer Service        Cashier           8            M
# 8253        Customer Service        Cashier          22            F
# 8252        Customer Service        Cashier          46            F
# 8251        Customer Service        Cashier          44            F
# 8250                   Dairy   Dairy Person           5            F
# ...                      ...            ...         ...          ...
# 3262                   Meats    Meat Cutter          18            F
# 3248                   Dairy   Dairy Person          35            F
# 4948                 Produce  Produce Clerk           5            F
# 3356                   Meats    Meat Cutter          18            F
# 4138                 Produce  Produce Clerk          31            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 8325              Male  Not Applicable  Not Applicable         2013
# 8253            Female  Not Applicable  Not Applicable         2013
# 8252            Female  Not Applicable  Not Applicable         2013
# 8251            Female  Not Applicable  Not Applicable         2013
# 8250            Female  Not Applicable  Not Applicable         2013
# ...                ...             ...             ...          ...
# 3262            Female      Retirement       Voluntary         2008
# 3248            Female      Retirement       Voluntary         2008
# 4948            Female      Retirement       Voluntary         2013
# 3356            Female      Retirement       Voluntary         2008
# 4138            Female      Retirement       Voluntary         2011
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 8325            ACTIVE        STORES
# 8253            ACTIVE        STORES
# 8252            ACTIVE        STORES
# 8251            ACTIVE        STORES
# 8250            ACTIVE        STORES
# ...                ...           ...
# 3262        TERMINATED        STORES
# 3248        TERMINATED        STORES
# 4948        TERMINATED        STORES
# 3356        TERMINATED        STORES
# 4138        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# ##### 3.D [BONUS] Using `sample` select any row

# %%
df.sample(1)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 3551        12/31/2014 0:00    11/20/1960        12/6/1995
#
#            terminationdate_key  age  length_of_service city_name  \
# EmployeeID
# 3551                  1/1/1900   54                 19   Burnaby
#
#             department_name      job_title  store_name gender_short  \
# EmployeeID
# 3551        Processed Foods  Shelf Stocker           5            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  STATUS  \
# EmployeeID
# 3551            Female  Not Applicable  Not Applicable         2014  ACTIVE
#
#            BUSINESS_UNIT
# EmployeeID
# 3551              STORES

# %% [markdown]
# # 4. Visualisation

# %% [markdown]
# #### 4.A Plot a histogram of `age`

# %%
plt.hist(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 4.B BoxPlot of `age`

# %%
plt.boxplot(df['age'])
plt.xlabel('Age')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# #### 4.C Create a scatterplot of `age` and `length_of_service`

# %%
plt.scatter(df['age'], df['length_of_service'])
plt.show()

# %% [markdown]
# #### 4.D Print a statistical summary of `age`

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
